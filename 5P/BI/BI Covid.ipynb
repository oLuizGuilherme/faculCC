# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
dados = pd.read_csv("MICRODADOS.csv", sep=";", encoding="latin-1")

# %%
dados_selecionados = dados[((dados['Municipio'] == 'CARIACICA') & (dados['ComorbidadeTabagismo'] == 'Sim') & (dados['DataObito'].between('2020-01-01', '2023-12-31')) & (dados['Evolucao'] == 'Óbito pelo COVID-19'))]
dados_selecionados
# Out:
#         DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 89798        2022-12-29   2022-12-29      2022-12-27               NaN
# 657935       2022-07-13   2022-07-13      2022-07-12        2022-07-13
# 777868       2022-07-04   2022-07-04      2022-07-04               NaN
# 792049       2022-07-04   2022-07-04      2022-07-04        2022-07-04
# 945621       2022-06-22   2022-06-22      2022-06-19               NaN
# ...                 ...          ...             ...               ...
# 4699848      2020-05-08   2020-05-08      2020-05-03        2020-05-08
# 4701039      2020-05-07   2020-05-08      2020-05-04        2020-05-07
# 4705728      2020-05-04   2020-05-04      2020-04-25        2020-05-05
# 4706214      2020-05-03   2020-05-03      2020-05-01        2020-05-02
# 4716255      2020-04-20   2020-04-20      2020-04-13        2020-04-20
#
#         DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# ...

# %%
porcentagem_selecionados = (dados_selecionados.shape[0]/dados.shape[0])*100

# %% [markdown]
# ### Dados
#
# Porcentagem das pessoas que morreram de covid-19 de 2020 a 2023, que fumavam e moravam na cidade de Cariacica.
# {{porcentagem_selecionados}}

# %%
engine = create_engine('postgresql://postgres:777@localhost:5432/covid_es')

# %%
dados.to_sql('fato_dados', engine, if_exists='replace')
