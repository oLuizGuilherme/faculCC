# %%
import pandas as pd

# %%
dados = pd.read_csv("MICRODADOS.csv", sep=";", encoding="latin-1")

# %%
dados
# Out:
#         DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0            2023-03-06   2023-03-06      2023-03-02               NaN
# 1            2023-03-06   2023-03-03      2023-03-02               NaN
# 2            2023-03-06   2023-03-06      2023-03-04               NaN
# 3            2023-03-06   2023-03-06      2023-03-06               NaN
# 4            2023-03-06   2023-03-06      2023-03-05               NaN
# ...                 ...          ...             ...               ...
# 4724840      2020-02-27   2020-04-16      2020-02-15        2020-02-27
# 4724841      2020-02-27   2020-04-16      2020-02-15        2020-02-27
# 4724842      2020-02-27   2020-04-15      2020-02-25        2020-02-26
# 4724843      2020-02-25   2020-04-16      2020-02-13        2020-02-26
# 4724844      2020-01-23   2020-10-25      2020-01-20               NaN
#
#         DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# 0                  2023-03-06                 NaN                    NaN
# 1                  2023-03-06                 NaN                    NaN
# 2                  2023-03-06                 NaN                    NaN
# 3                  2023-03-06                 NaN                    NaN
# 4                         NaN                 NaN                    NaN
# ...                       ...                 ...                    ...
# 4724840                   NaN                 NaN                    NaN
# 4724841                   NaN                 NaN                    NaN
# 4724842                   NaN                 NaN                    NaN
# 4724843                   NaN                 NaN                    NaN
# 4724844            2020-01-29                 NaN                    NaN
#
#         DataEncerramento   DataObito Classificacao  ...   ViagemBrasil  \
# 0             2023-03-06         NaN   Descartados  ...            Não
# 1             2023-03-03         NaN   Descartados  ...            Não
# 2             2023-03-06         NaN   Descartados  ...            Não
# 3             2023-03-06         NaN   Descartados  ...            Não
# 4                    NaN         NaN      Suspeito  ...            Não
# ...                  ...         ...           ...  ...            ...
# 4724840       2020-04-16         NaN   Descartados  ...            Não
# 4724841       2020-04-16         NaN   Descartados  ...            Não
# 4724842       2020-04-15         NaN   Descartados  ...  Não Informado
# 4724843       2020-04-16  2020-04-16   Descartados  ...            Não
# 4724844       2020-10-29         NaN   Descartados  ...       Ignorado
#
#         ViagemInternacional ProfissionalSaude PossuiDeficiencia  \
# 0                       Não               Não               Não
# 1                       Não               Não               Não
# 2                       Não               Não               Não
# 3                       Não               Não               Não
# 4                       Não               Sim               Não
# ...                     ...               ...               ...
# 4724840                 Não               Não     Não Informado
# 4724841                 Não               Não     Não Informado
# 4724842                 Sim               Não     Não Informado
# 4724843                 Sim               Não               Não
# 4724844                 Não               Não               Não
#
#           MoradorDeRua ResultadoRT_PCR ResultadoTesteRapido  \
# 0                  Não   Não Informado             Negativo
# 1                  Não   Não Informado             Negativo
# 2                  Não   Não Informado             Negativo
# 3                  Não   Não Informado             Negativo
# 4                  Não   Não Informado        Não Informado
# ...                ...             ...                  ...
# 4724840  Não Informado        Negativo        Não Informado
# 4724841  Não Informado        Negativo        Não Informado
# 4724842  Não Informado        Negativo        Não Informado
# 4724843            Não        Negativo        Não Informado
# 4724844            Não   Não Informado             Negativo
#
#         ResultadoSorologia ResultadoSorologia_IGG        TipoTesteRapido
# 0            Não Informado          Não Informado  Teste rápido Antígeno
# 1            Não Informado          Não Informado  Teste rápido Antígeno
# 2            Não Informado          Não Informado  Teste rápido Antígeno
# 3            Não Informado          Não Informado  Teste rápido Antígeno
# 4            Não Informado          Não Informado          Não Informado
# ...                    ...                    ...                    ...
# 4724840      Não Informado          Não Informado          Não Informado
# 4724841      Não Informado          Não Informado          Não Informado
# 4724842      Não Informado          Não Informado          Não Informado
# 4724843      Não Informado          Não Informado          Não Informado
# 4724844      Não Informado          Não Informado          Não Informado
#
# [4724845 rows x 45 columns]

# %%
colunas = list(dados.columns)
colunas
# Out:
# ['DataNotificacao',
#  'DataCadastro',
#  'DataDiagnostico',
#  'DataColeta_RT_PCR',
#  'DataColetaTesteRapido',
#  'DataColetaSorologia',
#  'DataColetaSorologiaIGG',
#  'DataEncerramento',
#  'DataObito',
#  'Classificacao',
#  'Evolucao',
#  'CriterioConfirmacao',
#  'StatusNotificacao',
#  'Municipio',
#  'Bairro',
#  'FaixaEtaria',
#  'IdadeNaDataNotificacao',
#  'Sexo',
#  'RacaCor',
#  'Escolaridade',
#  'Gestante',
#  'Febre',
#  'DificuldadeRespiratoria',
#  'Tosse',
#  'Coriza',
#  'DorGarganta',
#  'Diarreia',
#  'Cefaleia',
#  'ComorbidadePulmao',
#  'ComorbidadeCardio',
#  'ComorbidadeRenal',
#  'ComorbidadeDiabetes',
#  'ComorbidadeTabagismo',
#  'ComorbidadeObesidade',
#  'FicouInternado',
#  'ViagemBrasil',
#  'ViagemInternacional',
#  'ProfissionalSaude',
#  'PossuiDeficiencia',
#  'MoradorDeRua',
#  'ResultadoRT_PCR',
#  'ResultadoTesteRapido',
#  'ResultadoSorologia',
#  'ResultadoSorologia_IGG',
#  'TipoTesteRapido']

# %%
filtro_municipio = dados['Municipio'] == 'CARIACICA'

# %%
dados_cariacica = dados[filtro_municipio == True]

# %%
filtro_comorbidade = dados_cariacica['ComorbidadeTabagismo'] == 'Sim'

# %%
dados_cariacica_tabagismo = dados_cariacica[filtro_comorbidade]
dados_cariacica_tabagismo
# Out:
#         DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 1466         2023-03-05   2023-03-05      2023-02-27               NaN
# 2076         2023-03-04   2023-03-04      2023-02-27               NaN
# 2365         2023-03-04   2023-03-04      2023-03-02        2023-03-03
# 3601         2023-03-03   2023-03-03      2023-03-01               NaN
# 4544         2023-03-02   2023-03-02      2023-02-28               NaN
# ...                 ...          ...             ...               ...
# 4720984      2020-04-12   2020-04-12      2020-04-09        2020-04-11
# 4721516      2020-04-09   2020-04-09      2020-03-31        2020-04-09
# 4721653      2020-04-09   2020-04-09      2020-04-08               NaN
# 4721902      2020-04-08   2020-04-08      2020-04-06        2020-04-08
# 4722014      2020-04-08   2020-04-09      2020-04-07        2020-04-08
#
#         DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# 1466               2023-03-05                 NaN                    NaN
# 2076                      NaN                 NaN                    NaN
# 2365                      NaN                 NaN                    NaN
# 3601               2023-03-03                 NaN                    NaN
# 4544               2023-03-02                 NaN                    NaN
# ...                       ...                 ...                    ...
# 4720984                   NaN                 NaN                    NaN
# 4721516                   NaN                 NaN                    NaN
# 4721653                   NaN                 NaN                    NaN
# 4721902                   NaN                 NaN                    NaN
# 4722014                   NaN                 NaN                    NaN
#
#         DataEncerramento   DataObito Classificacao  ...   ViagemBrasil  \
# 1466          2023-03-06         NaN   Descartados  ...            Não
# 2076                 NaN         NaN      Suspeito  ...            Não
# 2365                 NaN         NaN      Suspeito  ...            Não
# 3601          2023-03-03         NaN   Descartados  ...            Não
# 4544                 NaN         NaN      Suspeito  ...            Não
# ...                  ...         ...           ...  ...            ...
# 4720984       2020-04-23  2020-02-04   Descartados  ...            Não
# 4721516       2020-04-23         NaN   Descartados  ...  Não Informado
# 4721653       2020-07-30         NaN   Descartados  ...            Não
# 4721902       2020-04-24         NaN   Descartados  ...            Não
# 4722014       2020-07-30         NaN   Descartados  ...            Não
#
#         ViagemInternacional ProfissionalSaude PossuiDeficiencia  \
# 1466                    Não               Não               Não
# 2076                    Não               Não               Não
# 2365                    Não               Não               Não
# 3601                    Não               Não               Não
# 4544                    Não               Não               Não
# ...                     ...               ...               ...
# 4720984                 Não               Não               Não
# 4721516       Não Informado     Não Informado     Não Informado
# 4721653                 Não               Não               Não
# 4721902                 Não     Não Informado     Não Informado
# 4722014                 Não          Ignorado               Não
#
#           MoradorDeRua ResultadoRT_PCR ResultadoTesteRapido  \
# 1466               Não   Não Informado             Negativo
# 2076               Não   Não Informado        Não Informado
# 2365               Não   Não Informado        Não Informado
# 3601               Não   Não Informado             Negativo
# 4544               Não   Não Informado             Negativo
# ...                ...             ...                  ...
# 4720984            Não        Negativo        Não Informado
# 4721516  Não Informado        Negativo        Não Informado
# 4721653            Não   Não Informado        Não Informado
# 4721902  Não Informado        Negativo        Não Informado
# 4722014            Não        Negativo        Não Informado
#
#         ResultadoSorologia ResultadoSorologia_IGG        TipoTesteRapido
# 1466         Não Informado          Não Informado  Teste rápido Antígeno
# 2076         Não Informado          Não Informado          Não Informado
# 2365         Não Informado          Não Informado          Não Informado
# 3601         Não Informado          Não Informado  Teste rápido Antígeno
# 4544         Não Informado          Não Informado  Teste rápido Antígeno
# ...                    ...                    ...                    ...
# 4720984      Não Informado          Não Informado          Não Informado
# 4721516      Não Informado          Não Informado          Não Informado
# 4721653      Não Informado          Não Informado          Não Informado
# 4721902      Não Informado          Não Informado          Não Informado
# 4722014      Não Informado          Não Informado          Não Informado
#
# [4342 rows x 45 columns]
